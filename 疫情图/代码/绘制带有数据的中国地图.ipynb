# %%
from pyecharts import Map
import random
import pandas as pd

# %%
from province_city import province_city

# %%
province_name = province_city.keys()

# %%
province_value = []
for i in range(len(province_name)):
    province_value.append(random.randint(1,1000))

# %%
china = Map("中国地图",'中国地图',width=800,height=600)

# %%
china.add("测试画出中国地图", province_name , province_value , maptype='china',visual_range=[0,1000] , is_visualmap=True , isule_text_color="#000", is_label_show=True)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="afc13028e0094e97bc6354575675f718" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_afc13028e0094e97bc6354575675f718 = echarts.init(document.getElementById('afc13028e0094e97bc6354575675f718'), 'light', {renderer: 'canvas'});
#
# var option_afc13028e0094e97bc6354575675f718 = {
#     "title": [
#         {
#             "text": "\u4e2d\u56fd\u5730\u56fe",
#             "subtext": "\u4e2d\u56fd\u5730\u56fe",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
# ...

# %%
china.render(path="province_map/"+"中国_map.html")
